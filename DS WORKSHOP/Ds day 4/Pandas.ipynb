# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn
np.random.seed(101)

# %%
df = pd.DataFrame(randn(10,4),columns='W X Y Z'.split())

# %%
df.head()
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 2 -2.018168  0.740122  0.528813 -0.589001
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509

# %%
df.head(2)
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965

# %%
df.tail()
# Out:
#           W         X         Y         Z
# 5  0.302665  1.693723 -1.706086 -1.159119
# 6 -0.134841  0.390528  0.166905  0.184502
# 7  0.807706  0.072960  0.638787  0.329646
# 8 -0.497104 -0.754070 -0.943406  0.484752
# 9 -0.116773  1.901755  0.238127  1.996652

# %%
df.tail(2)
# Out:
#           W         X         Y         Z
# 8 -0.497104 -0.754070 -0.943406  0.484752
# 9 -0.116773  1.901755  0.238127  1.996652

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.shape
# Out:
# (10, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       10 non-null     float64
#  1   X       10 non-null     float64
#  2   Y       10 non-null     float64
#  3   Z       10 non-null     float64
# dtypes: float64(4)
# memory usage: 448.0 bytes

# %%
df.describe()
# Out:
#                W          X          Y          Z
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.208094   0.557372   0.065576   0.399579
# std     1.177846   1.034991   1.235387   0.847120
# min    -2.018168  -0.758872  -1.706086  -1.159119
# 25%    -0.130324  -0.221249  -0.911947   0.220788
# 50%     0.189745   0.509330   0.202516   0.494289
# 75%     0.564005   1.455323   0.611294   0.664123
# max     2.706850   1.978757   2.605967   1.996652

# %%
df = pd.DataFrame(randn(10,4),index='A B C D E F G H I J'.split(),columns='W X Y Z'.split())
df.head()
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %% [markdown]
# ## Selection and Indexing

# %%
df['W']
# Out:
# A   -0.993263
# B    1.025984
# C    2.154846
# D    0.147027
# E   -0.925874
# F    0.386030
# G    0.681209
# H   -1.005187
# I   -1.382920
# J    0.992573
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'W'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-118-3099918c1bad> in <cell line: 1>()
# ----> 1 type(df['W'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'W'

# %%
# Pass a list of column names
df[['W','Z']]
# Out:
#           W         Z
# A -0.993263  0.000366
# B  1.025984  0.649826
# C  2.154846 -0.346419
# D  0.147027  1.024810
# E -0.925874  0.610478
# F  0.386030  0.230336
# G  0.681209  1.939932
# H -1.005187 -0.732845
# I -1.382920 -2.141212
# J  0.992573  1.292765

# %%
type(df[['W', 'Z']])
# Out:
# pandas.core.frame.DataFrame

# %%
# SQL Syntax (NOT RECOMMENDED!)
df.W
# Out:
# A   -0.993263
# B    1.025984
# C    2.154846
# D    0.147027
# E   -0.925874
# F    0.386030
# G    0.681209
# H   -1.005187
# I   -1.382920
# J    0.992573
# Name: W, dtype: float64

# %% [markdown]
# **Creating a new column:**

# %%
df['new'] = df['W'] + df['Y'] # can perform any arithmatic operation
df.head()
# Out:
#           W         X         Y         Z       new
# A -0.993263  0.196800 -1.136645  0.000366 -2.129908
# B  1.025984 -0.156598 -0.031579  0.649826  0.994405
# C  2.154846 -0.610259 -0.755325 -0.346419  1.399521
# D  0.147027 -0.479448  0.558769  1.024810  0.705796
# E -0.925874  1.862864 -1.133817  0.610478 -2.059691

# %%
df['new2'] = df['W']**2 + df['Y'] + df['W'] + df['X'] # can perform any arithmatic operation
df.head()
# Out:
#           W         X         Y         Z       new      new2
# A -0.993263  0.196800 -1.136645  0.000366 -2.129908 -0.946536
# B  1.025984 -0.156598 -0.031579  0.649826  0.994405  1.890451
# C  2.154846 -0.610259 -0.755325 -0.346419  1.399521  5.432625
# D  0.147027 -0.479448  0.558769  1.024810  0.705796  0.247965
# E -0.925874  1.862864 -1.133817  0.610478 -2.059691  0.660416

# %%
df['new3'] = 1 # can perform any arithmatic operation
df.head()
# Out:
#           W         X         Y         Z       new      new2  new3
# A -0.993263  0.196800 -1.136645  0.000366 -2.129908 -0.946536     1
# B  1.025984 -0.156598 -0.031579  0.649826  0.994405  1.890451     1
# C  2.154846 -0.610259 -0.755325 -0.346419  1.399521  5.432625     1
# D  0.147027 -0.479448  0.558769  1.024810  0.705796  0.247965     1
# E -0.925874  1.862864 -1.133817  0.610478 -2.059691  0.660416     1

# %%
df['new3'].unique()
# Out:
# array([1])

# %%
df['new3'].nunique()
# Out:
# 1

# %%
df['W'].max()
# Out:
# 2.154846443259472

# %%
df['W'].mean()
# Out:
# 0.10804256502627649

# %%
df['W'].median()
# Out:
# 0.26652854171883766

# %% [markdown]
# ** Removing Columns**

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z      new2  new3
# A -0.993263  0.196800 -1.136645  0.000366 -0.946536     1
# B  1.025984 -0.156598 -0.031579  0.649826  1.890451     1
# C  2.154846 -0.610259 -0.755325 -0.346419  5.432625     1
# D  0.147027 -0.479448  0.558769  1.024810  0.247965     1
# E -0.925874  1.862864 -1.133817  0.610478  0.660416     1
# F  0.386030  2.084019 -0.376519  0.230336  2.242550     1
# G  0.681209  1.035125 -0.031160  1.939932  2.149220     1
# H -1.005187 -0.741790  0.187125 -0.732845 -0.549451     1
# I -1.382920  1.482495  0.961458 -2.141212  2.973502     1
# J  0.992573  1.192241 -1.046780  1.292765  2.123237     1

# %%
df
# Out:
#           W         X         Y         Z       new      new2  new3
# A -0.993263  0.196800 -1.136645  0.000366 -2.129908 -0.946536     1
# B  1.025984 -0.156598 -0.031579  0.649826  0.994405  1.890451     1
# C  2.154846 -0.610259 -0.755325 -0.346419  1.399521  5.432625     1
# D  0.147027 -0.479448  0.558769  1.024810  0.705796  0.247965     1
# E -0.925874  1.862864 -1.133817  0.610478 -2.059691  0.660416     1
# F  0.386030  2.084019 -0.376519  0.230336  0.009512  2.242550     1
# G  0.681209  1.035125 -0.031160  1.939932  0.650049  2.149220     1
# H -1.005187 -0.741790  0.187125 -0.732845 -0.818062 -0.549451     1
# I -1.382920  1.482495  0.961458 -2.141212 -0.421462  2.973502     1
# J  0.992573  1.192241 -1.046780  1.292765 -0.054206  2.123237     1

# %%
df = df.drop('new',axis=1) # Axis 0 means rows, axis 1 means columns
df
# Out:
#           W         X         Y         Z      new2  new3
# A -0.993263  0.196800 -1.136645  0.000366 -0.946536     1
# B  1.025984 -0.156598 -0.031579  0.649826  1.890451     1
# C  2.154846 -0.610259 -0.755325 -0.346419  5.432625     1
# D  0.147027 -0.479448  0.558769  1.024810  0.247965     1
# E -0.925874  1.862864 -1.133817  0.610478  0.660416     1
# F  0.386030  2.084019 -0.376519  0.230336  2.242550     1
# G  0.681209  1.035125 -0.031160  1.939932  2.149220     1
# H -1.005187 -0.741790  0.187125 -0.732845 -0.549451     1
# I -1.382920  1.482495  0.961458 -2.141212  2.973502     1
# J  0.992573  1.192241 -1.046780  1.292765  2.123237     1

# %%
df = df.drop(['new2','new3'],axis=1)
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478
# F  0.386030  2.084019 -0.376519  0.230336
# G  0.681209  1.035125 -0.031160  1.939932
# H -1.005187 -0.741790  0.187125 -0.732845
# I -1.382920  1.482495  0.961458 -2.141212
# J  0.992573  1.192241 -1.046780  1.292765

# %% [markdown]
# Can also drop rows this way:

# %%
df = df.drop('E',axis=0)
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# F  0.386030  2.084019 -0.376519  0.230336
# G  0.681209  1.035125 -0.031160  1.939932
# H -1.005187 -0.741790  0.187125 -0.732845
# I -1.382920  1.482495  0.961458 -2.141212
# J  0.992573  1.192241 -1.046780  1.292765

# %%
df = df.drop(['F','G','H','I','J'],axis=0)
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %% [markdown]
# ** Selecting Rows**

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# F  0.386030  2.084019 -0.376519  0.230336
# G  0.681209  1.035125 -0.031160  1.939932
# H -1.005187 -0.741790  0.187125 -0.732845
# I -1.382920  1.482495  0.961458 -2.141212
# J  0.992573  1.192241 -1.046780  1.292765

# %%
df.loc['A']
# Out:
# W   -0.993263
# X    0.196800
# Y   -1.136645
# Z    0.000366
# Name: A, dtype: float64

# %%
df.loc[['A','B']]
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826

# %% [markdown]
# Or select based off of position instead of label

# %%
df.iloc[2]
# Out:
# W    2.154846
# X   -0.610259
# Y   -0.755325
# Z   -0.346419
# Name: C, dtype: float64

# %%
df.iloc[2:5]
# Out:
#           W         X         Y         Z
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
df.iloc[1::2]
# Out:
#           W         X         Y         Z
# B  1.025984 -0.156598 -0.031579  0.649826
# D  0.147027 -0.479448  0.558769  1.024810

# %% [markdown]
# ** Selecting subset of rows and columns **

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
df.loc['B','Y']
# Out:
# -0.031579143908112575

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A -0.993263 -1.136645
# B  1.025984 -0.031579

# %% [markdown]
# ### Conditional Selection
#
# An important feature of pandas is conditional selection using bracket notation, very similar to numpy:

# %%
df
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 2 -2.018168  0.740122  0.528813 -0.589001
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509
# 5  0.302665  1.693723 -1.706086 -1.159119
# 6 -0.134841  0.390528  0.166905  0.184502
# 7  0.807706  0.072960  0.638787  0.329646
# 8 -0.497104 -0.754070 -0.943406  0.484752
# 9 -0.116773  1.901755  0.238127  1.996652

# %%
df > 0
# Out:
#        W      X      Y      Z
# 0   True   True   True   True
# 1   True  False  False   True
# 2  False   True   True  False
# 3   True  False  False   True
# 4   True   True   True   True
# 5   True   True  False  False
# 6  False   True   True   True
# 7   True   True   True   True
# 8  False  False  False   True
# 9  False   True   True   True

# %%
df[df['W'] > 0]
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509
# 5  0.302665  1.693723 -1.706086 -1.159119
# 7  0.807706  0.072960  0.638787  0.329646

# %%
df[df['W'] > 0]['Y']
# Out:
# 0    0.907969
# 1   -0.848077
# 3   -0.933237
# 4    2.605967
# 5   -1.706086
# 7    0.638787
# Name: Y, dtype: float64

# %%
df[df['W'] > 0][['Y','X']]
# Out:
#           Y         X
# 0  0.907969  0.628133
# 1 -0.848077 -0.319318
# 3 -0.933237 -0.758872
# 4  2.605967  1.978757
# 5 -1.706086  1.693723
# 7  0.638787  0.072960

# %% [markdown]
# For two conditions you can use | and & with parenthesis:

# %%
df
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 2 -2.018168  0.740122  0.528813 -0.589001
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509
# 5  0.302665  1.693723 -1.706086 -1.159119
# 6 -0.134841  0.390528  0.166905  0.184502
# 7  0.807706  0.072960  0.638787  0.329646
# 8 -0.497104 -0.754070 -0.943406  0.484752
# 9 -0.116773  1.901755  0.238127  1.996652

# %%
df[(df['W'] > 0) & (df['Y'] > 0)]
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 4  0.190794  1.978757  2.605967  0.683509
# 7  0.807706  0.072960  0.638787  0.329646

# %%
df[(df['W'] > 0) | (df['Y'] > 1)]
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509
# 5  0.302665  1.693723 -1.706086 -1.159119
# 7  0.807706  0.072960  0.638787  0.329646

# %% [markdown]
# ## More Index Details
#
# Let's discuss some more features of indexing, including resetting the index or setting it something else. We'll also talk about index hierarchy!

# %%
df
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 2 -2.018168  0.740122  0.528813 -0.589001
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509
# 5  0.302665  1.693723 -1.706086 -1.159119
# 6 -0.134841  0.390528  0.166905  0.184502
# 7  0.807706  0.072960  0.638787  0.329646
# 8 -0.497104 -0.754070 -0.943406  0.484752
# 9 -0.116773  1.901755  0.238127  1.996652

# %%
# Reset to default 0,1...n index
df.reset_index()
# Out:
#    index         W         X         Y         Z
# 0      0  2.706850  0.628133  0.907969  0.503826
# 1      1  0.651118 -0.319318 -0.848077  0.605965
# 2      2 -2.018168  0.740122  0.528813 -0.589001
# 3      3  0.188695 -0.758872 -0.933237  0.955057
# 4      4  0.190794  1.978757  2.605967  0.683509
# 5      5  0.302665  1.693723 -1.706086 -1.159119
# 6      6 -0.134841  0.390528  0.166905  0.184502
# 7      7  0.807706  0.072960  0.638787  0.329646
# 8      8 -0.497104 -0.754070 -0.943406  0.484752
# 9      9 -0.116773  1.901755  0.238127  1.996652

# %%
newind = 'CA NY WY NY'.split()
newind
# Out:
# ['CA', 'NY', 'WY', 'NY']

# %%
df['States'] = newind
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-b48234e86c04> in <cell line: 1>()
# ----> 1 df['States'] = newind
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
#    4313     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
#    4526         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    5264
#    5265         if is_list_like(value):
# -> 5266             com.require_length_match(value, self.index)
#    5267         arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     571     """
#     572     if len(data) != len(index):
# --> 573         raise ValueError(
#     574             "Length of values "
#     575             f"({len(data)}) "
#
# ValueError: Length of values (4) does not match length of index (10)

# %%
df
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 2 -2.018168  0.740122  0.528813 -0.589001
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509
# 5  0.302665  1.693723 -1.706086 -1.159119
# 6 -0.134841  0.390528  0.166905  0.184502
# 7  0.807706  0.072960  0.638787  0.329646
# 8 -0.497104 -0.754070 -0.943406  0.484752
# 9 -0.116773  1.901755  0.238127  1.996652

# %%
df['States'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'States'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-5e9fd736eb34> in <cell line: 1>()
# ----> 1 df['States'].value_counts()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'States'

# %%
df.set_index('States')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-f106b3d4debf> in <cell line: 1>()
# ----> 1 df.set_index('States')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['States'] are in the columns"

# %%
df
# Out:
#           W         X         Y         Z
# 0  2.706850  0.628133  0.907969  0.503826
# 1  0.651118 -0.319318 -0.848077  0.605965
# 2 -2.018168  0.740122  0.528813 -0.589001
# 3  0.188695 -0.758872 -0.933237  0.955057
# 4  0.190794  1.978757  2.605967  0.683509
# 5  0.302665  1.693723 -1.706086 -1.159119
# 6 -0.134841  0.390528  0.166905  0.184502
# 7  0.807706  0.072960  0.638787  0.329646
# 8 -0.497104 -0.754070 -0.943406  0.484752
# 9 -0.116773  1.901755  0.238127  1.996652

# %% [markdown]
# # Missing Data
#
# Let's show a few convenient methods to deal with Missing Data in pandas:

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.isna()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
df.isna().sum()
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %%
df.isna().mean()
# Out:
# A    0.333333
# B    0.666667
# C    0.000000
# dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.fillna(value='FILL VALUE')
# Out:
#             A           B  C
# 0         1.0         5.0  1
# 1         2.0  FILL VALUE  2
# 2  FILL VALUE  FILL VALUE  3

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %% [markdown]
# # Groupby
#
# The groupby method allows you to group rows of data together and call aggregate functions

# %%
import pandas as pd
# Our data: dictionary of lists
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %% [markdown]
# ** Now you can use the .groupby() method to group rows together based off of a column name. For instance let's group based off of Company. This will create a DataFrameGroupBy object:**

# %%
df.groupby('Company')

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
by_comp = df.groupby("Company")['Sales'].mean()

print(by_comp)
# Out:
# Company
# FB      296.5
# GOOG    160.0
# MSFT    232.0
# Name: Sales, dtype: float64

# %%
by_comp = df.groupby("Company")['Sales'].sum()

print(by_comp)
# Out:
# Company
# FB      593
# GOOG    320
# MSFT    464
# Name: Sales, dtype: int64

# %%
by_comp = df.groupby("Company")['Sales'].max()

print(by_comp)
# Out:
# Company
# FB      350
# GOOG    200
# MSFT    340
# Name: Sales, dtype: int64

# %%
by_comp = df.groupby("Company")['Sales'].min()

print(by_comp)
# Out:
# Company
# FB      243
# GOOG    120
# MSFT    124
# Name: Sales, dtype: int64

# %% [markdown]
# ### Example DataFrames

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# ## Concatenation

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df1 = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6]
})

df2 = pd.DataFrame({
    'C': ['a', 'b', 'c'],
    'D': ['x', 'y', 'z']
})

# %%
df1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df2
# Out:
#    C  D
# 0  a  x
# 1  b  y
# 2  c  z

# %%
pd.concat([df1, df2], axis=1)
# Out:
#    A  B  C  D
# 0  1  4  a  x
# 1  2  5  b  y
# 2  3  6  c  z

# %% [markdown]
# # Operations

# %%
import pandas as pd
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %% [markdown]
# ### Applying Functions

# %%
def times2(x):
    return x*2

df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col1'].apply(lambda x:x*2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %% [markdown]
# ** Sorting and Ordering a DataFrame:**

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
data = {
    'col1': [3, 1, 2, 3, 2],
    'col2': [5, 4, 3, 2, 1],
    'col3': ['A', 'B', 'C', 'D', 'E']
}

df = pd.DataFrame(data)
df
# Out:
#    col1  col2 col3
# 0     3     5    A
# 1     1     4    B
# 2     2     3    C
# 3     3     2    D
# 4     2     1    E

# %%
df.sort_values(by='col2')
# Out:
#    col1  col2 col3
# 4     2     1    E
# 3     3     2    D
# 2     2     3    C
# 1     1     4    B
# 0     3     5    A

# %%
df.sort_values(by='col2',ascending=False)
# Out:
#    col1  col2 col3
# 0     3     5    A
# 1     1     4    B
# 2     2     3    C
# 3     3     2    D
# 4     2     1    E

# %% [markdown]
# # read and write to files

# %%
import pandas as pd


# Step 1: Create a sample DataFrame



df = pd.DataFrame()

df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
csv_file = 'Titanic-Dataset.csv'
df.to_csv(csv_file, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1ecb77bf64c5> in <cell line: 3>()
#       1 import pandas as pd
#       2 csv_file = 'Titanic-Dataset.csv'
# ----> 3 df.to_csv(csv_file, index=False)
#
# NameError: name 'df' is not defined

# %%
read_df = pd.read_csv(csv_file)
read_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b938ac58c528> in <cell line: 1>()
# ----> 1 read_df = pd.read_csv(csv_file)
#       2 read_df
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# Step 1: Create a sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}

df = pd.DataFrame(data)  # Define df here

csv_file = 'Titanic-Dataset.csv'
df.to_csv(csv_file, index=False) # Now df is defined in this scope
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-14-1af3962d8ca7> in <cell line: 2>()
#       1 from google.colab import sheets
# ----> 2 sheet = sheets.InteractiveSheet(df=df)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/sheets.py in __init__(self, title, url, sheet_id, df, worksheet_id, worksheet_name, credentials, include_column_headers, display)
#     110       url = f'https://docs.google.com/spreadsheets/d/{sheet_id}'
#     111     self._credentials = credentials
# --> 112     self._ensure_gspread_client()
#     113
#     114     self.sheet = self._load_or_create_sheet(url, title)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/sheets.py in _ensure_gspread_client(self)
#     166     global _gspread_client
#     167     if _gspread_client is None:
# --> 168       creds = InteractiveSheet.generate_creds(self._credentials)
#     169       _gspread_client = gspread.authorize(creds)
#     170
#
# /usr/local/lib/python3.10/dist-packages/google/colab/sheets.py in generate_creds(cls, credentials)
#     171   @classmethod
#     172   def generate_creds(cls, credentials=None):
# --> 173     return _generate_creds(credentials)
#     174
#     175   def as_df(self):
#
# /usr/local/lib/python3.10/dist-packages/google/colab/sheets.py in _generate_creds(unused_credentials)
#      33
#      34 def _generate_creds(unused_credentials=None):
# ---> 35   auth.authenticate_user()
#      36   scopes = (
#      37       'https://www.googleapis.com/auth/drive',
#
# /usr/local/lib/python3.10/dist-packages/google/colab/auth.py in authenticate_user(clear_output, project_id)
#     258   if not _check_adc(_CredentialType.USER):
#     259     if use_auth_ephem:
# --> 260       _message.blocking_request(
#     261           'request_auth',
#     262           request={'authType': 'auth_user_ephemeral'},
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
#pd.read_excel csv (comma seperated file)
#pd.read_excel .xlsx
#pd.read_html .html
